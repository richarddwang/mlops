# %%
import mlflow

exp = mlflow.get_experiment_by_name("MLops Test")
runs = mlflow.search_runs(experiment_names=["MLops Test"])
runs
# Out:
#                              run_id       experiment_id    status  \
# 0  1b9c22f3667848c7b2ac9bdb07d8c2c4  762448250173551023  FINISHED
# 1  9eefd232249a4df891c622623deb9c75  762448250173551023  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/762448250173551023/1b9c22f36...
# 1  mlflow-artifacts:/762448250173551023/9eefd2322...
#
#                         start_time                         end_time  \
# 0 2023-10-27 00:55:18.931000+00:00 2023-10-27 00:55:50.540000+00:00
# 1 2023-10-27 00:52:51.269000+00:00 2023-10-27 00:53:18.900000+00:00
#
#    metrics.training_loss  metrics.validation_loss params.differentiable  \
# 0            3221.598633              2036.759888                 False
# 1            3193.403809              9654.370117                 False
#
#   params.capturable  ... params.maximize params.epochs  params.betas  \
# 0             False  ...           False             3  (0.9, 0.999)
# ...

# %%
from mlflow.client import MlflowClient

client = MlflowClient()
new_name = "newname"
client.update_run(run_id=runs.run_id[0], name=new_name)

# %%
def rename_runs(names: list[str], params: dict[list]) -> list[str]:
